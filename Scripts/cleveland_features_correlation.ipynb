# %%
# %pylab inline
import pandas as pd
from scipy.stats import mode
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
names = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
df = pd.read_csv('../Datasets/processed_cleveland_data.csv', sep=';', names=names)

# %%
missingData_index = [11,12]

# %%
for data in missingData_index:
    df.fillna(mode(df.iloc[data]).mode[0], inplace=True)

# %%
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 5    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 6    62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# 7    57.0  0.0  4.0     120.0  354.0  0.0      0.0    163.0    1.0      0.6
# 8    63.0  1.0  4.0     130.0  254.0  0.0      2.0    147.0    0.0      1.4
# 9    53.0  1.0  4.0     140.0  203.0  1.0      2.0    155.0    1.0      3.1
# 10   57.0  1.0  4.0     140.0  192.0  0.0      0.0    148.0    0.0      0.4
# ...

# %% [markdown]
# # Coeficiente de Covariância

# %%
df.cov()
# Out:
#                 age       sex        cp    trestbps         chol       fbs  \
# age       81.697419 -0.411995  0.903744   45.328678    97.787489  0.381614
# sex       -0.411995  0.218368  0.004524   -0.530107    -4.836994  0.007967
# cp         0.903744  0.004524  0.921841   -0.609632     3.595141 -0.013671
# trestbps  45.328678 -0.530107 -0.609632  309.751120   118.573339  1.099207
# chol      97.787489 -4.836994  3.595141  118.573339  2680.849190  0.181496
# fbs        0.381614  0.007967 -0.013671    1.099207     0.181496  0.126877
# restecg    1.338797  0.010065  0.064488    2.566455     8.811521  0.024654
# thalach  -81.423065 -0.520184 -7.344863  -18.258005    -4.064651 -0.063996
# exang      0.389220  0.032096  0.173235    0.535473     1.491345  0.004295
# oldpeak    2.138850  0.055436  0.225493    3.865638     2.799282  0.002377
# slope      0.901034  0.010808  0.089961    1.273053    -0.129598  0.013147
# ...

# %%
df.cov().loc['num']
# Out:
# age          2.474636
# sex          0.128866
# cp           0.480165
# trestbps     3.410946
# chol         4.510491
# fbs          0.025900
# restecg      0.224543
# thalach    -11.663782
# exang        0.229165
# oldpeak      0.719048
# slope        0.286134
# ca           0.598026
# thal         1.206478
# num          1.509300
# Name: num, dtype: float64

# %% [markdown]
# # Coeficiente de Correlação de Pearson

# %%
df.corr(method='pearson')
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.097542  0.104139  0.284946  0.208950  0.118530
# sex      -0.097542  1.000000  0.010084 -0.064456 -0.199915  0.047862
# cp        0.104139  0.010084  1.000000 -0.036077  0.072319 -0.039975
# trestbps  0.284946 -0.064456 -0.036077  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.072319  0.130120  1.000000  0.009841
# fbs       0.118530  0.047862 -0.039975  0.175340  0.009841  1.000000
# restecg   0.148868  0.021647  0.067505  0.146560  0.171043  0.069564
# thalach  -0.393806 -0.048663 -0.334422 -0.045351 -0.003432 -0.007854
# exang     0.091661  0.146201  0.384060  0.064762  0.061310  0.025665
# oldpeak   0.203805  0.102173  0.202277  0.189171  0.046564  0.005747
# slope     0.161770  0.037533  0.152050  0.117382 -0.004062  0.059894
# ca        0.365323  0.086048  0.233117  0.097528  0.123726  0.140764
# thal      0.128340  0.378155  0.254161  0.134311  0.025190  0.053608
# ...

# %%
df.corr(method='pearson').loc['num']
# Out:
# age         0.222853
# sex         0.224469
# cp          0.407075
# trestbps    0.157754
# chol        0.070909
# fbs         0.059186
# restecg     0.183696
# thalach    -0.415040
# exang       0.397057
# oldpeak     0.504092
# slope       0.377957
# ca          0.520968
# thal        0.498238
# num         1.000000
# Name: num, dtype: float64

# %% [markdown]
# # Coeficiente de correlação de Postos de Kendall

# %%
df.corr(method='kendall')
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.082692  0.098916  0.205814  0.132025  0.091872
# sex      -0.082692  1.000000  0.039446 -0.051116 -0.126613  0.047862
# cp        0.098916  0.039446  1.000000  0.002127  0.057016 -0.041571
# trestbps  0.205814 -0.051116  0.002127  1.000000  0.092775  0.126574
# chol      0.132025 -0.126613  0.057016  0.092775  1.000000  0.011659
# fbs       0.091872  0.047862 -0.041571  0.126574  0.011659  1.000000
# restecg   0.122192  0.021392  0.089709  0.118950  0.138364  0.069073
# thalach  -0.275696 -0.037487 -0.293193 -0.027960 -0.025789 -0.011050
# exang     0.069958  0.146201  0.403723  0.042686  0.069798  0.025665
# oldpeak   0.187074  0.093408  0.197867  0.106372  0.027306  0.024342
# slope     0.141551  0.031357  0.189513  0.067954  0.002130  0.044546
# ca        0.309652  0.091314  0.231764  0.059858  0.114818  0.123888
# thal      0.104880  0.361554  0.270775  0.088542  0.016238  0.048487
# ...

# %%
df.corr(method='kendall').loc['num']
# Out:
# age         0.187547
# sex         0.239189
# cp          0.419369
# trestbps    0.107179
# chol        0.086346
# fbs         0.047903
# restecg     0.166676
# thalach    -0.343509
# exang       0.403729
# oldpeak     0.373256
# slope       0.364461
# ca          0.477179
# thal        0.477434
# num         1.000000
# Name: num, dtype: float64

# %% [markdown]
# # Coeficiente de Correlação de Postos de Spearman

# %%
df.corr(method='spearman')
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.099627  0.127748  0.292183  0.191253  0.110688
# sex      -0.099627  1.000000  0.042222 -0.060905 -0.154403  0.047862
# cp        0.127748  0.042222  1.000000  0.001771  0.075466 -0.044496
# trestbps  0.292183 -0.060905  0.001771  1.000000  0.135837  0.150812
# chol      0.191253 -0.154403  0.075466  0.135837  1.000000  0.014219
# fbs       0.110688  0.047862 -0.044496  0.150812  0.014219  1.000000
# restecg   0.147927  0.021528  0.096271  0.142866  0.170718  0.069510
# thalach  -0.391633 -0.045542 -0.375564 -0.040401 -0.038301 -0.013424
# exang     0.084286  0.146201  0.432136  0.050861  0.085118  0.025665
# oldpeak   0.259895  0.108838  0.246493  0.150192  0.034359  0.028363
# slope     0.176386  0.032229  0.207511  0.083565  0.002703  0.045786
# ca        0.386569  0.096631  0.261587  0.076049  0.144962  0.131101
# thal      0.131993  0.371411  0.299802  0.108006  0.020247  0.049809
# ...

# %%
df.corr(method='spearman').loc['num']
# Out:
# age         0.241696
# sex         0.257866
# cp          0.486933
# trestbps    0.137164
# chol        0.109293
# fbs         0.051643
# restecg     0.181248
# thalach    -0.443944
# exang       0.435255
# oldpeak     0.463032
# slope       0.400302
# ca          0.530939
# thal        0.528637
# num         1.000000
# Name: num, dtype: float64
